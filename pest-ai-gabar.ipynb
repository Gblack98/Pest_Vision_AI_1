# %%
import os
import gc
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Suppress excessive TF logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Enable mixed precision (bfloat16) for TPU/GPU
tf.keras.mixed_precision.set_global_policy('mixed_bfloat16')

# Initialize TPU strategy or fallback to GPU/CPU
try:
    # For TPU VM on Kaggle, specify 'local'
    resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='local')
    tf.config.experimental_connect_to_cluster(resolver)
    tf.tpu.experimental.initialize_tpu_system(resolver)
    strategy = tf.distribute.TPUStrategy(resolver)
    print("✅ TPU detected and initialized")
except Exception as e:
    print(f"⚠️ TPU initialization failed: {e}")
    strategy = tf.distribute.MirroredStrategy()
    print("✅ Using MirroredStrategy (GPU/CPU)")

print(f"🚀 Number of replicas: {strategy.num_replicas_in_sync}")

# Global parameters
IMG_SIZE = (384, 384)
SEED = 42
EPOCH_HEAD = 5
EPOCH_FINE = 15
AUTOTUNE = tf.data.AUTOTUNE

# Directories
dataset_root = '/kaggle/input/niayes-crops-disease-v2'
train_dir = os.path.join(dataset_root, 'train')
val_dir   = os.path.join(dataset_root, 'val')
test_dir  = os.path.join(dataset_root, 'test')

CLASS_NAMES = sorted(os.listdir(train_dir))
NUM_CLASSES = len(CLASS_NAMES)
print(f"Categories detected: {CLASS_NAMES}")

# Compute batch size per replica
GLOBAL_BATCH_SIZE = 128 * strategy.num_replicas_in_sync

# Data pipeline

def build_dataset(directory, shuffle=False, augment=False):
    ds = image_dataset_from_directory(
        directory,
        image_size=IMG_SIZE,
        batch_size=GLOBAL_BATCH_SIZE,
        shuffle=shuffle,
        seed=SEED,
        label_mode='int',
        interpolation='bilinear'
    )

    def preprocess(image, label):
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        label = tf.one_hot(label, NUM_CLASSES)
        return image, label

    ds = ds.map(preprocess, num_parallel_calls=AUTOTUNE)

    if augment:
        augmentation = tf.keras.Sequential([
            layers.RandomFlip('horizontal'),
            layers.RandomRotation(0.15),
            layers.RandomZoom(0.1),
            layers.RandomContrast(0.1),
        ])
        ds = ds.map(lambda x, y: (augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)

    return ds.cache().prefetch(buffer_size=AUTOTUNE)

train_ds = build_dataset(train_dir, shuffle=True, augment=True)
val_ds   = build_dataset(val_dir)
test_ds  = build_dataset(test_dir)

# Calculate class weights
counts = np.array([len(os.listdir(os.path.join(train_dir, cls))) for cls in CLASS_NAMES])
labels = np.concatenate([np.full(c, i) for i, c in enumerate(counts)])
weights = compute_class_weight('balanced', classes=np.arange(NUM_CLASSES), y=labels)
class_weights = dict(enumerate(weights))
print("Class weights:", class_weights)

# Model construction under strategy scope
with strategy.scope():
    base_model = EfficientNetV2B0(
        include_top=False,
        weights='imagenet',
        input_shape=(*IMG_SIZE, 3),
        pooling='avg'
    )
    base_model.trainable = False

    inputs = layers.Input(shape=(*IMG_SIZE, 3))
    x = base_model(inputs, training=False)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax', dtype='float32')(x)
    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

model.summary()

# Callbacks
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True),
    ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, min_lr=1e-6)
]

# Phase 1: Train top layers
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCH_HEAD,
    class_weight=class_weights,
    callbacks=callbacks
)

# Phase 2: Fine-tuning
with strategy.scope():
    base_model.trainable = True
    for layer in base_model.layers[:100]:
        layer.trainable = False

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    initial_epoch=history.epoch[-1],
    epochs=history.epoch[-1] + EPOCH_FINE,
    class_weight=class_weights,
    callbacks=callbacks
)

# Evaluation
loss, acc = model.evaluate(test_ds, verbose=0)
print(f"Final test accuracy: {acc*100:.2f}%")

y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_pred = np.argmax(model.predict(test_ds), axis=1)

print(classification_report(y_true.argmax(axis=1), y_pred, target_names=CLASS_NAMES))

plt.figure(figsize=(12, 8))
cm = confusion_matrix(y_true.argmax(axis=1), y_pred)
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks(np.arange(NUM_CLASSES), CLASS_NAMES, rotation=90)
plt.yticks(np.arange(NUM_CLASSES), CLASS_NAMES)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()

# Cleanup
tf.keras.backend.clear_session()
gc.collect()


# --- Save the final model ---

save_dir = '/kaggle/working/final_model'
os.makedirs(save_dir, exist_ok=True)


# Sauvegarde au format Keras (.keras) et TensorFlow SavedModel
model.save(os.path.join(save_dir, 'model_final.keras'))
model.save(os.path.join(save_dir, 'model_final_savedmodel.keras'))
# Out:
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1745869044.119962      10 common_lib.cc:612] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="local"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:230
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745869063.413483      10 service.cc:148] XLA service 0x588b75cae330 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745869063.413524      10 service.cc:156]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1745869063.413528      10 service.cc:156]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1745869063.413531      10 service.cc:156]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1745869063.413534      10 service.cc:156]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1745869063.413537      10 service.cc:156]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1745869063.413539      10 service.cc:156]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1745869063.413542      10 service.cc:156]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1745869063.413545      10 service.cc:156]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# ✅ TPU detected and initialized
# 🚀 Number of replicas: 8
# Categories detected: ['Bell_pepper__Bell_pepper_Bacterial_spot', 'Bell_pepper__Bell_pepper_Healthy', 'Brinjal__Diseased_Brinjal_Leaf_-_Cercospora_Leaf_Spot', 'Brinjal__Fresh_Brinjal_Leaf', 'Cabbage__Alternaria_Leaf_Spot', 'Cabbage__Bacterial_spot_rot', 'Cabbage__Black_Rot', 'Cabbage__Cabbage_aphid_colony', 'Cabbage__Downy_Mildew', 'Cabbage__Healthy', 'Cabbage__club_root', 'Cabbage__ring_spot', 'Citrus__Citrus_Black_spot', 'Citrus__Citrus_Healthy', 'Citrus__Citrus_canker', 'Citrus__Citrus_greening', 'Corn__Corn_Common_rust', 'Corn__Corn_Gray_leaf_spot', 'Corn__Corn_Healthy', 'Corn__Corn_Northern_Leaf_Blight', 'Lettuce__Bacterial', 'Lettuce__fungal', 'Lettuce__healthy', 'Potato__Potato_Early_blight', 'Potato__Potato_Healthy', 'Potato__Potato_Late_blight', 'Tomato__Tomato_Bacterial_spot', 'Tomato__Tomato_Early_blight', 'Tomato__Tomato_Healthy', 'Tomato__Tomato_Late_blight', 'Tomato__Tomato_Leaf_Mold', 'Tomato__Tomato_Mosaic_virus', 'Tomato__Tomato_Septoria_leaf_spot', 'Tomato__Tomato_Spider_mites', 'Tomato__Tomato_Target_Spot', 'Tomato__Tomato_Yellow_Leaf_Curl_Virus']
# Found 59152 files belonging to 36 classes.
# Found 12666 files belonging to 36 classes.
# Found 12705 files belonging to 36 classes.
# Class weights: {0: np.float64(0.6806591181073368), 1: np.float64(0.5849452157746925), 2: np.float64(2.260125324774568), 3: np.float64(1.9964898069393817), 4: np.float64(11.736507936507936), 5: np.float64(11.736507936507936), 6: np.float64(11.736507936507936), 7: np.float64(11.736507936507936), 8: np.float64(11.736507936507936), 9: np.float64(11.736507936507936), 10: np.float64(11.736507936507936), 11: np.float64(11.736507936507936), 12: np.float64(13.14488888888889), 13: np.float64(54.77037037037037), 14: np.float64(10.600716845878136), 15: np.float64(0.4196963246771676), 16: np.float64(0.6376061742767214), 17: np.float64(0.8929951690821256), 18: np.float64(0.6734061930783243), 19: np.float64(0.6620109230906974), 20: np.float64(3.0038594353036765), 21: np.float64(3.4519140989729227), 22: np.float64(2.0411318150448587), 23: np.float64(0.6646889608054657), 24: np.float64(0.9654001827914871), 25: np.float64(0.6668470418470418), 26: np.float64(0.5390784485272674), 27: np.float64(0.675066191910892), 28: np.float64(0.5791720518544629), 29: np.float64(0.5429977234339428), 30: np.float64(0.6927112610080569), 31: np.float64(0.8843439779930631), 32: np.float64(0.5739123685333954), 33: np.float64(0.6092366003378239), 34: np.float64(0.6366180205777261), 35: np.float64(0.2980430094524054)}
# I0000 00:00:1745869095.010461      10 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 384, 384, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 1280)           │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast_1 (Cast)                   │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 36)             │        46,116 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,970,548 (22.78 MB)
#  Trainable params: 48,676 (190.14 KB)
#  Non-trainable params: 5,921,872 (22.59 MB)
# Epoch 1/5
# I0000 00:00:1745869231.166182      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:79802313285003334
# I0000 00:00:1745869288.389000     960 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(15673926079641369166), session_name()
# I0000 00:00:1745869336.731142     960 tpu_compile_op_common.cc:245] Compilation of 15673926079641369166 with session name  took 48.342088267s and succeeded
# I0000 00:00:1745869336.827724     960 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(15673926079641369166), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_79802313285003334", property.function_library_fingerprint = 13842425826496859019, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "128,384,384,3,;128,36,;128,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745869336.827775     960 tpu_compilation_cache_interface.cc:542] After adding entry for key 15673926079641369166 with session_name  cache is 1 entries (112740991 bytes),  marked for eviction 0 entries (0 bytes).
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 1s 2s/step - accuracy: nan - loss: nan
# I0000 00:00:1745869431.044219     949 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(3105534044925405352), session_name()
# I0000 00:00:1745869463.408147     949 tpu_compile_op_common.cc:245] Compilation of 3105534044925405352 with session name  took 32.363882384s and succeeded
# I0000 00:00:1745869463.490586     949 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(3105534044925405352), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_79802313285003334", property.function_library_fingerprint = 13842425826496859019, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "98,384,384,3,;98,36,;98,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745869463.490646     949 tpu_compilation_cache_interface.cc:542] After adding entry for key 3105534044925405352 with session_name  cache is 2 entries (226046945 bytes),  marked for eviction 0 entries (0 bytes).
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: nan - loss: nan
# I0000 00:00:1745869476.837672      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:18240903483417694070
# I0000 00:00:1745869479.896578     889 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(17826099240063545923), session_name()
# I0000 00:00:1745869488.792547     889 tpu_compile_op_common.cc:245] Compilation of 17826099240063545923 with session name  took 8.89591024s and succeeded
# I0000 00:00:1745869488.812263     889 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(17826099240063545923), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_18240903483417694070", property.function_library_fingerprint = 12971573089098855185, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "128,384,384,3,;128,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745869488.812309     889 tpu_compilation_cache_interface.cc:542] After adding entry for key 17826099240063545923 with session_name  cache is 3 entries (259632081 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1745869502.475794     875 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(13591758673044511774), session_name()
# I0000 00:00:1745869517.964210     875 tpu_compile_op_common.cc:245] Compilation of 13591758673044511774 with session name  took 15.488361623s and succeeded
# I0000 00:00:1745869517.978147     875 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(13591758673044511774), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_18240903483417694070", property.function_library_fingerprint = 12971573089098855185, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "48,384,384,3,;48,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745869517.978186     875 tpu_compilation_cache_interface.cc:542] After adding entry for key 13591758673044511774 with session_name  cache is 4 entries (291665298 bytes),  marked for eviction 0 entries (0 bytes).
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 297s 3s/step - accuracy: nan - loss: nan - val_accuracy: 0.6400 - val_loss: 1.3446 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.8831 - val_loss: 0.7583 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9480 - val_loss: 0.4287 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9641 - val_loss: 0.2675 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9723 - val_loss: 0.1825 - learning_rate: 0.0010
# Epoch 5/19
# I0000 00:00:1745869851.973606      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:3069325908835980696
# I0000 00:00:1745869857.992846     945 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(12470664160065605227), session_name()
# I0000 00:00:1745869909.592175     945 tpu_compile_op_common.cc:245] Compilation of 12470664160065605227 with session name  took 51.599257631s and succeeded
# I0000 00:00:1745869909.762771     945 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(12470664160065605227), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_3069325908835980696", property.function_library_fingerprint = 11286459513549786179, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "128,384,384,3,;128,36,;128,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745869909.762865     945 tpu_compilation_cache_interface.cc:542] After adding entry for key 12470664160065605227 with session_name  cache is 5 entries (517780171 bytes),  marked for eviction 0 entries (0 bytes).
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: nan - loss: nan
# I0000 00:00:1745869963.191066     964 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(3819891145682823243), session_name()
# I0000 00:00:1745870016.321530     964 tpu_compile_op_common.cc:245] Compilation of 3819891145682823243 with session name  took 53.13039333s and succeeded
# I0000 00:00:1745870016.453779     964 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(3819891145682823243), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_3069325908835980696", property.function_library_fingerprint = 11286459513549786179, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "98,384,384,3,;98,36,;98,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745870016.453862     964 tpu_compilation_cache_interface.cc:542] After adding entry for key 3819891145682823243 with session_name  cache is 6 entries (740977556 bytes),  marked for eviction 0 entries (0 bytes).
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: nan - loss: nan
# I0000 00:00:1745870025.938704      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:4211816026037321731
# I0000 00:00:1745870028.054538     927 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(584513229379306074), session_name()
# I0000 00:00:1745870035.399507     927 tpu_compile_op_common.cc:245] Compilation of 584513229379306074 with session name  took 7.344855682s and succeeded
# I0000 00:00:1745870035.420478     927 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(584513229379306074), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_4211816026037321731", property.function_library_fingerprint = 4499424274785145359, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "128,384,384,3,;128,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745870035.420526     927 tpu_compilation_cache_interface.cc:542] After adding entry for key 584513229379306074 with session_name  cache is 7 entries (774562692 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1745870049.568805     872 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(17557141682915159754), session_name()
# I0000 00:00:1745870065.366490     872 tpu_compile_op_common.cc:245] Compilation of 17557141682915159754 with session name  took 15.785048525s and succeeded
# I0000 00:00:1745870065.386133     872 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(17557141682915159754), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_4211816026037321731", property.function_library_fingerprint = 4499424274785145359, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "48,384,384,3,;48,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745870065.386180     872 tpu_compilation_cache_interface.cc:542] After adding entry for key 17557141682915159754 with session_name  cache is 8 entries (806595909 bytes),  marked for eviction 0 entries (0 bytes).
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 230s 3s/step - accuracy: nan - loss: nan - val_accuracy: 0.8636 - val_loss: 0.7542 - learning_rate: 1.0000e-05
# Epoch 6/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9317 - val_loss: 0.4131 - learning_rate: 1.0000e-05
# Epoch 7/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9493 - val_loss: 0.2664 - learning_rate: 1.0000e-05
# Epoch 8/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9538 - val_loss: 0.2056 - learning_rate: 1.0000e-05
# Epoch 9/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9586 - val_loss: 0.1763 - learning_rate: 1.0000e-05
# Epoch 10/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9618 - val_loss: 0.1561 - learning_rate: 1.0000e-05
# Epoch 11/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9630 - val_loss: 0.1441 - learning_rate: 1.0000e-05
# Epoch 12/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9637 - val_loss: 0.1346 - learning_rate: 1.0000e-05
# Epoch 13/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9657 - val_loss: 0.1272 - learning_rate: 1.0000e-05
# Epoch 14/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9669 - val_loss: 0.1220 - learning_rate: 1.0000e-05
# Epoch 15/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9691 - val_loss: 0.1176 - learning_rate: 1.0000e-05
# Epoch 16/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9709 - val_loss: 0.1137 - learning_rate: 1.0000e-05
# Epoch 17/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9710 - val_loss: 0.1096 - learning_rate: 1.0000e-05
# Epoch 18/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9717 - val_loss: 0.1066 - learning_rate: 1.0000e-05
# Epoch 19/19
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: nan - loss: nan - val_accuracy: 0.9715 - val_loss: 0.1038 - learning_rate: 1.0000e-05
# I0000 00:00:1745871206.169230     964 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(14450205245648733717), session_name()
# I0000 00:00:1745871224.264830     964 tpu_compile_op_common.cc:245] Compilation of 14450205245648733717 with session name  took 18.095448684s and succeeded
# I0000 00:00:1745871224.284647     964 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(14450205245648733717), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_4211816026037321731", property.function_library_fingerprint = 4499424274785145359, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "53,384,384,3,;53,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745871224.284688     964 tpu_compilation_cache_interface.cc:542] After adding entry for key 14450205245648733717 with session_name  cache is 9 entries (838984279 bytes),  marked for eviction 0 entries (0 bytes).
# Final test accuracy: 96.99%
# I0000 00:00:1745871231.304971      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:10423039639582751152
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745871231.550913      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1_1/batch_normalization_1/Cast_1/ReadVariableOp.
# I0000 00:00:1745871232.122694     941 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(15375351218633553782), session_name()
# I0000 00:00:1745871238.425595     941 tpu_compile_op_common.cc:245] Compilation of 15375351218633553782 with session name  took 6.302836442s and succeeded
# I0000 00:00:1745871238.439614     941 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(15375351218633553782), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_10423039639582751152", property.function_library_fingerprint = 3162513273952053015, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745871238.439647     941 tpu_compilation_cache_interface.cc:542] After adding entry for key 15375351218633553782 with session_name  cache is 10 entries (871642339 bytes),  marked for eviction 0 entries (0 bytes).
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 2s 3s/step
# I0000 00:00:1745871275.952774      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:17639558513426433498
# I0000 00:00:1745871276.943389     925 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(14695135205338634989), session_name()
# I0000 00:00:1745871293.644839     925 tpu_compile_op_common.cc:245] Compilation of 14695135205338634989 with session name  took 16.701406687s and succeeded
# I0000 00:00:1745871293.658073     925 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(14695135205338634989), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_17639558513426433498", property.function_library_fingerprint = 15694328538886699869, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "53,384,384,3,;53,36,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1745871293.658108     925 tpu_compilation_cache_interface.cc:542] After adding entry for key 14695135205338634989 with session_name  cache is 11 entries (903170348 bytes),  marked for eviction 0 entries (0 bytes).
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 69s 5s/step
#                                                        precision    recall  f1-score   support
#
#               Bell_pepper__Bell_pepper_Bacterial_spot       0.97      0.96      0.97       518
#                      Bell_pepper__Bell_pepper_Healthy       0.96      0.98      0.97       603
# Brinjal__Diseased_Brinjal_Leaf_-_Cercospora_Leaf_Spot       1.00      0.98      0.99       157
#                           Brinjal__Fresh_Brinjal_Leaf       0.98      1.00      0.99       178
#                         Cabbage__Alternaria_Leaf_Spot       0.85      0.97      0.91        30
#                           Cabbage__Bacterial_spot_rot       0.88      0.97      0.92        30
#                                    Cabbage__Black_Rot       0.86      1.00      0.92        30
#                         Cabbage__Cabbage_aphid_colony       0.97      0.97      0.97        30
#                                 Cabbage__Downy_Mildew       0.83      0.97      0.89        30
#                                      Cabbage__Healthy       1.00      1.00      1.00        30
#                                    Cabbage__club_root       0.94      1.00      0.97        30
#                                    Cabbage__ring_spot       0.79      1.00      0.88        30
#                             Citrus__Citrus_Black_spot       0.48      0.96      0.64        28
#                                Citrus__Citrus_Healthy       0.47      0.88      0.61         8
#                                 Citrus__Citrus_canker       0.59      0.71      0.64        34
#                               Citrus__Citrus_greening       0.99      0.98      0.98       840
#                                Corn__Corn_Common_rust       0.99      0.97      0.98       553
#                             Corn__Corn_Gray_leaf_spot       0.92      0.84      0.88       395
#                                    Corn__Corn_Healthy       0.99      1.00      1.00       524
#                       Corn__Corn_Northern_Leaf_Blight       0.88      0.95      0.91       533
#                                    Lettuce__Bacterial       0.74      0.84      0.79       118
#                                       Lettuce__fungal       0.76      0.70      0.73       103
#                                      Lettuce__healthy       0.90      0.97      0.93       173
#                           Potato__Potato_Early_blight       0.97      0.97      0.97       531
#                                Potato__Potato_Healthy       0.97      0.98      0.97       366
#                            Potato__Potato_Late_blight       0.96      0.97      0.96       529
#                         Tomato__Tomato_Bacterial_spot       0.92      0.94      0.93       654
#                           Tomato__Tomato_Early_blight       0.95      0.76      0.85       523
#                                Tomato__Tomato_Healthy       0.96      0.96      0.96       609
#                            Tomato__Tomato_Late_blight       0.90      0.92      0.91       649
#                              Tomato__Tomato_Leaf_Mold       0.95      0.93      0.94       509
#                           Tomato__Tomato_Mosaic_virus       0.97      0.95      0.96       399
#                     Tomato__Tomato_Septoria_leaf_spot       0.90      0.89      0.89       615
#                           Tomato__Tomato_Spider_mites       0.92      0.93      0.92       579
#                            Tomato__Tomato_Target_Spot       0.86      0.94      0.90       554
#                 Tomato__Tomato_Yellow_Leaf_Curl_Virus       1.00      0.96      0.98      1183
#
#                                              accuracy                           0.94     12705
#                                             macro avg       0.89      0.93      0.91     12705
#                                          weighted avg       0.94      0.94      0.94     12705

# %%
print(f"✅ Model saved at: {save_dir}")

# --- Script to reload and test the model ---

# Chargement du modèle (Keras ou SavedModel)
model_reloaded = tf.keras.models.load_model(os.path.join(save_dir, 'model_final.keras'))
print("✅ Model successfully reloaded!")

# Evaluation rapide sur le test set
loss_reload, acc_reload = model_reloaded.evaluate(test_ds, verbose=0)
print(f"Reloaded model test accuracy: {acc_reload*100:.2f}%")

# Prédictions reload pour confirmation
y_pred_reload = np.argmax(model_reloaded.predict(test_ds), axis=1)

print("\nReloaded model classification report:")
print(classification_report(y_true.argmax(axis=1), y_pred_reload, target_names=CLASS_NAMES))
# Out:
# ✅ Model saved at: /kaggle/working/final_model
# ✅ Model successfully reloaded!
# Reloaded model test accuracy: 93.86%
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 534s 41s/step
#
# Reloaded model classification report:
#                                                        precision    recall  f1-score   support
#
#               Bell_pepper__Bell_pepper_Bacterial_spot       0.97      0.96      0.97       518
#                      Bell_pepper__Bell_pepper_Healthy       0.96      0.98      0.97       603
# Brinjal__Diseased_Brinjal_Leaf_-_Cercospora_Leaf_Spot       1.00      0.99      0.99       157
#                           Brinjal__Fresh_Brinjal_Leaf       0.98      1.00      0.99       178
#                         Cabbage__Alternaria_Leaf_Spot       0.85      0.97      0.91        30
#                           Cabbage__Bacterial_spot_rot       0.85      0.97      0.91        30
#                                    Cabbage__Black_Rot       0.86      1.00      0.92        30
#                         Cabbage__Cabbage_aphid_colony       0.97      0.97      0.97        30
#                                 Cabbage__Downy_Mildew       0.83      0.97      0.89        30
#                                      Cabbage__Healthy       1.00      1.00      1.00        30
#                                    Cabbage__club_root       0.94      1.00      0.97        30
#                                    Cabbage__ring_spot       0.79      1.00      0.88        30
#                             Citrus__Citrus_Black_spot       0.49      0.96      0.65        28
#                                Citrus__Citrus_Healthy       0.47      0.88      0.61         8
#                                 Citrus__Citrus_canker       0.61      0.74      0.67        34
#                               Citrus__Citrus_greening       0.99      0.98      0.98       840
#                                Corn__Corn_Common_rust       0.99      0.97      0.98       553
#                             Corn__Corn_Gray_leaf_spot       0.92      0.84      0.88       395
#                                    Corn__Corn_Healthy       0.99      1.00      1.00       524
#                       Corn__Corn_Northern_Leaf_Blight       0.88      0.95      0.91       533
#                                    Lettuce__Bacterial       0.75      0.84      0.79       118
#                                       Lettuce__fungal       0.76      0.70      0.73       103
#                                      Lettuce__healthy       0.90      0.98      0.94       173
#                           Potato__Potato_Early_blight       0.97      0.97      0.97       531
#                                Potato__Potato_Healthy       0.97      0.98      0.97       366
#                            Potato__Potato_Late_blight       0.96      0.96      0.96       529
#                         Tomato__Tomato_Bacterial_spot       0.93      0.93      0.93       654
#                           Tomato__Tomato_Early_blight       0.95      0.76      0.84       523
#                                Tomato__Tomato_Healthy       0.97      0.95      0.96       609
#                            Tomato__Tomato_Late_blight       0.89      0.91      0.90       649
#                              Tomato__Tomato_Leaf_Mold       0.94      0.93      0.94       509
#                           Tomato__Tomato_Mosaic_virus       0.97      0.95      0.96       399
#                     Tomato__Tomato_Septoria_leaf_spot       0.89      0.89      0.89       615
#                           Tomato__Tomato_Spider_mites       0.92      0.93      0.93       579
#                            Tomato__Tomato_Target_Spot       0.86      0.94      0.90       554
#                 Tomato__Tomato_Yellow_Leaf_Curl_Virus       1.00      0.96      0.98      1183
#
#                                              accuracy                           0.94     12705
#                                             macro avg       0.89      0.94      0.91     12705
#                                          weighted avg       0.94      0.94      0.94     12705
